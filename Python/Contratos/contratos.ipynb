# %%
import pandas as pd

# %%
path = "2019.csv"
df = pd.read_csv(path)
df
# Out:
#                                             NombreEntidad  \
# 0       CORPOAMAZONIA - CORPORACION PARA EL DESARROLLO...
# 1       SECRETARIA DISTRITAL DE SEGURIDAD  CONVIVENCIA...
# 2                           ALCALDIA MUNICIPAL FUSAGASUGA
# 3       INSTITUTO DISTRITAL DE LA PARTICIPACION Y ACCI...
# 4       COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE ...
# ...                                                   ...
# 139023  SUBRED INTEGRADA DE SERVICIOS DE SALUD CENTRO ...
# 139024  UNIDAD ADMINISTRATIVA ESPECIAL DE GESTION DE R...
# 139025                 ALCALDIA DISTRITAL BARRANCABERMEJA
# 139026  UARIV-UNIDAD PARA LA ATENCION Y REPARACION INT...
# 139027                         ALCALDIA LOCAL DE FONTIBON
#
#                       Departamento       Ciudad  \
# 0                         Putumayo        Mocoa
# 1       Distrito Capital de Bogota  No Definido
# 2                     Cundinamarca   Fusagasuga
# 3       Distrito Capital de Bogota  No Definido
# ...

# %%
extracto = df.loc[:,["NombreEntidad", "Departamento", "ProveedorAdjudicado", "ValordelContrato"]]
extracto.sort_values(by = "ValordelContrato", ascending = False, inplace = True)
extracto.reset_index(drop = True, inplace = True)

print(extracto.loc[0:9])
# Out:
#                                        NombreEntidad  \
# 0          SENA DIRECCION GENERAL Direccion Juridica
# 1  EMPRESA DE TRANSPORTE DEL TERCER MILENIO TRANS...
# 2  INSTITUTO DISTRITAL DE DEPORTE Y RECREACION DE...
# 3  FONDO ROTATORIO DEL MINISTERIO DE RELACIONES E...
# 4                         DISPENSARIO MEDICO DE CALI
# 5  SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...
# 6               DIRECCION GENERAL DE SANIDAD MILITAR
# 7                     INSTITUTO DE DESARROLLO URBANO
# 8             MINISTERIO DE EDUCACION NACIONAL (MEN)
# 9  UNIDAD DE SERVICIOS PENITENCIARIOS Y CARCELARI...
#
#                  Departamento  \
# 0  Distrito Capital de Bogota
# 1  Distrito Capital de Bogota
# 2                     Bolivar
# 3  Distrito Capital de Bogota
# 4             Valle del Cauca
# 5  Distrito Capital de Bogota
# 6  Distrito Capital de Bogota
# 7  Distrito Capital de Bogota
# 8  Distrito Capital de Bogota
# 9  Distrito Capital de Bogota
#
# ...
